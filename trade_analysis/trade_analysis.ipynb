# %%
from trade_analysis import Trade_Analyzer

# %% [markdown]
# #### Set the players in the trade

# %%
my_players = [
    "Buddy Hield",
    "Jalen Suggs",
    "Brandon Boston Jr"
]

away_players = [
    "Cameron Johnson",
    "Donte Divincenzo",
    "Jarrett Allen"
]

# %% [markdown]
# #### Analyze the trade

# %%
Trade_Analyzer(my_players, away_players)
